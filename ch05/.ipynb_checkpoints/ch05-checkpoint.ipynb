# %%
# %matplotlib inline
df_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data', header=None)
df_wine.columns = ['Class label', 'Alcohol', 'Malic acid', 'Ash',
                   'Alcalinity of ash', 'Magnesium', 'Total phenols',
                   'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanius',
                   'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline']
print(df_wine['Class label'].unique())
df_wine.head()
# Out:
# [1 2 3]
#    Class label  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0            1    14.23        1.71  2.43               15.6        127
# 1            1    13.20        1.78  2.14               11.2        100
# 2            1    13.16        2.36  2.67               18.6        101
# 3            1    14.37        1.95  2.50               16.8        113
# 4            1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanius  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# ...

# %%
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler

X, y = df_wine.iloc[:, 1:].values, df_wine.iloc[:, 0].values
X_train, X_test, y_train, y_test =\
    train_test_split(X, y, test_size=0.3, random_state=0)

sc = StandardScaler()
X_train_std = sc.fit_transform(X_train)
X_test_std = sc.transform(X_test)
# Out:
# /Users/katsuta/anaconda/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from matplotlib.colors import ListedColormap

def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):
    markers = ['s', '^', 'o', 'v', 'x']
    colors = ['red', 'blue', 'lightgreen', 'gray', 'cyan']
    cmap = ListedColormap(colors[: len(np.unique(y))])
    
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                                              np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    
    plt.figure(figsize=(12, 8))
    plt.contourf(xx1, xx2, Z, alhpa=0.2, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())
    
    for i, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0],
                            y=X[y == cl, 1],
                            alpha=0.8, c=cmap(i),
                            marker=markers[i], label=cl)
    if test_idx:
        X_test, y_test = X[test_idx, :], y[test_idx]
        plt.scatter(X_test[:, 0], X_test[:, 1], 
                           c='', alpha=1.0, marker='o', s=55, 
                           linewidths=1, label='test set')
    plt.legend(loc='best')

# %%
print(X_train_std.shape)
cov_mat = np.cov(X_train_std.T)
eigen_vals, eigen_vecs = np.linalg.eig(cov_mat)
print(eigen_vals)
# Out:
# (124, 13)
# [ 4.8923083   2.46635032  1.42809973  1.01233462  0.84906459  0.60181514
#   0.52251546  0.08414846  0.33051429  0.29595018  0.16831254  0.21432212
#   0.2399553 ]

# %%
v = sorted(eigen_vals, reverse=True) / sum(eigen_vals)
cumsum_eigen_vals = np.cumsum(v)
x = range(1, 14)
plt.bar(x, v, align='center')
plt.step(x, cumsum_eigen_vals, where='mid')

# %%
eigen_pairs = list(zip(eigen_vals, eigen_vecs.T))
eigen_pairs.sort(key=lambda k: abs(k[0]), reverse=True)
w = np.hstack([eigen_pairs[0][1][:, np.newaxis], eigen_pairs[1][1][:, np.newaxis]])
w
# Out:
# array([[ 0.14669811,  0.50417079],
#        [-0.24224554,  0.24216889],
#        [-0.02993442,  0.28698484],
#        [-0.25519002, -0.06468718],
#        [ 0.12079772,  0.22995385],
#        [ 0.38934455,  0.09363991],
#        [ 0.42326486,  0.01088622],
#        [-0.30634956,  0.01870216],
#        [ 0.30572219,  0.03040352],
#        [-0.09869191,  0.54527081],
#        [ 0.30032535, -0.27924322],
#        [ 0.36821154, -0.174365  ],
#        [ 0.29259713,  0.36315461]])

# %%
X_train_pca = X_train_std.dot(w)
X_train_pca.shape
# Out:
# (124, 2)

# %%
colors = list('rgb')
markers = list('sxo')

for i, c in enumerate(np.unique(y_train)):
    plt.scatter(X_train_pca[y_train==c, 0], X_train_pca[y_train==c, 1],
                marker=markers[i], color=colors[i], label=c)
plt.legend(loc='best')
plt.xlabel('PC1')
plt.ylabel('PC2')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train_std)
X_test_pca = pca.transform(X_test_std)

lr = LogisticRegression()
lr.fit(X_train_pca, y_train)

X_pca_combined = np.vstack([X_train_pca, X_test_pca])
y_combined = np.hstack([y_train, y_test])
# print(X_train_pca.shape, y_test.shape)
plot_decision_regions(X_pca_combined, y_combined, lr, test_idx=range(124, 178))
plt.xlabel('PC1')
plt.ylabel('PC2')

# %% [markdown]
# ## 5.2 LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=2)

X_train_lda = lda.fit_transform(X_train_std, y_train)
X_test_lda = lda.transform(X_test_std)
X_lda_combined = np.vstack([X_train_lda, X_test_lda])
y_combined = np.hstack([y_train, y_test])

lr = LogisticRegression()
lr.fit(X_train_lda, y_train)
plot_decision_regions(X_lda_combined, y_combined, lr, test_idx=range(124, 178))
plt.xlabel('LD1')
plt.ylabel('LD2')

# %% [markdown]
# ## 5.3 kernel PCA

# %%
from scipy.spatial.distance import pdist, squareform
from scipy import exp
from scipy.linalg import eigh
import numpy as np

def rbf_kernel_pca(X, gamma, n_components):
    mat_sq_dists = squareform(pdist(X, 'sqeuclidean'))
    K = exp(-gamma * mat_sq_dists)
    
    N = K.shape[0]
    one_n = np.ones((N, N)) / float(N)
    K = K - one_n.dot(K) - K.dot(one_n) + one_n.dot(K).dot(one_n)
    
    eigvals, eigvecs = eigh(K)
    X_pc = np.column_stack([eigvecs[:, -i] for i in range(1, n_components + 1)])
    return X_pc

# %%
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=100, random_state=123)
plt.scatter(X[y==0, 0], X[y==0, 1], marker='^')
plt.scatter(X[y==1, 0], X[y==1, 1], marker='o')

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(12, 4))
plt.subplot(121)
plt.scatter(X[y==0, 0], X[y==0, 1], marker='^')
plt.scatter(X[y==1, 0], X[y==1, 1], marker='o')
plt.xlabel('x1')
plt.ylabel('x2')

plt.subplot(122)
plt.scatter(X_pca[y==0, 0], X_pca[y==0, 1], marker='^')
plt.scatter(X_pca[y==1, 0], X_pca[y==1, 1], marker='o')
plt.xlabel('pc1')
plt.ylabel('pc2')

# %%
from matplotlib.ticker import FormatStrFormatter
X_kpca = rbf_kernel_pca(X, gamma=15, n_components=2)

plt.figure(figsize=(12, 4))
plt.subplot(121)
plt.scatter(X_pca[y==0, 0], X_pca[y==0, 1], marker='^')
plt.scatter(X_pca[y==1, 0], X_pca[y==1, 1], marker='o')
plt.xlabel('pc1')
plt.ylabel('pc2')

plt.subplot(122)
plt.scatter(X_kpca[y==0, 0], X_kpca[y==0, 1], marker='^')
plt.scatter(X_kpca[y==1, 0], X_kpca[y==1, 1], marker='o')
plt.xlabel('kpc1')
plt.ylabel('kpc2')

# %%
from sklearn.datasets import make_circles
X, y = make_circles(n_samples=1000, random_state=123, noise=0.1, factor=0.2)
plt.scatter(X[y==0, 0], X[y==0, 1], marker='o', color='g')
plt.scatter(X[y==1, 0], X[y==1, 1], marker='^', color='b')

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
X_kpca = rbf_kernel_pca(X, gamma=15, n_components=2)

plt.figure(figsize=(12, 4))
plt.subplot(121)
plt.scatter(X_pca[y==0, 0], X_pca[y==0, 1], marker='^', color='g')
plt.scatter(X_pca[y==1, 0], X_pca[y==1, 1], marker='o', color='b')
plt.xlabel('pc1')
plt.ylabel('pc2')

plt.subplot(122)
plt.scatter(X_kpca[y==0, 0], X_kpca[y==0, 1], marker='^', color='g')
plt.scatter(X_kpca[y==1, 0], X_kpca[y==1, 1], marker='o', color='b')
plt.xlabel('kpc1')
plt.ylabel('kpc2')

# %%
from scipy.spatial.distance import pdist, squareform
from scipy import exp
from scipy.linalg import eigh
import numpy as np

def rbf_kernel_pca2(X, gamma, n_components):
    mat_sq_dists = squareform(pdist(X, 'sqeuclidean'))
    K = exp(-gamma * mat_sq_dists)
    
    N = K.shape[0]
    one_n = np.ones((N, N)) / float(N)
    K = K - one_n.dot(K) - K.dot(one_n) + one_n.dot(K).dot(one_n)
    
    eigvals, eigvecs = eigh(K)
    alphas = np.column_stack([eigvecs[:, -i] for i in range(1, n_components + 1)])
    lambdas = np.column_stack([eigvals[-i] for i in range(1, n_components + 1)])
    return alphas, lambdas


def project_x(x_new, X, gamma, alphas, lambdas):
    pair_dist = np.array([np.sum((x_new - row)**2) for row in X])
    k = np.exp(-gamma * pair_dist)
    return k.dot(alphas / lambdas)

# %%
X, y = make_moons(n_samples=100, random_state=123)
alphas, lambdas = rbf_kernel_pca2(X, gamma=15, n_components=1)

x_new = X[25]
x_proj = alphas[25]
x_reproj = project_x(x_new, X, 15, alphas, lambdas)
print(x_new, x_proj, x_reproj)
# Out:
# [ 1.8713187   0.00928245] [ 0.07877284] [ 0.07877284]

# %%
from sklearn.decomposition import KernelPCA
X, y = make_moons(n_samples=100, random_state=123)
scikit_kpca = KernelPCA(n_components=2, kernel='rbf', gamma=15)
X_skpca = scikit_kpca.fit_transform(X)

plt.scatter(X_skpca[y==0, 0], X_skpca[y==0, 1], marker='^')
plt.scatter(X_skpca[y==1, 0], X_skpca[y==1, 1], marker='o')
plt.xlabel('skpc1')
plt.ylabel('skpc2')
